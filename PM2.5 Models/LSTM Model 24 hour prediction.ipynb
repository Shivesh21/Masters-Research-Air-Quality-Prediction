# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

pd.set_option('display.max_columns', None)

# %%
# read data
data_for_model = pd.read_csv('Combined Station Data.csv')
#data_for_model.drop(columns=['anomaly'], inplace=True)
data_for_model
# Out:
#                        Date      Wind   Wind Dir    SO2     NO2    NOX  \
# 0       2016/01/15 16:10:00  5.726794  101.24370  25.67   0.808  18.10
# 1       2016/01/15 16:20:00  5.942719  101.66950  20.56   1.167  17.69
# 2       2016/01/15 16:30:00  6.538234   94.81412  17.24   1.212  12.66
# 3       2016/01/15 16:40:00  7.156286   91.86486  13.81   1.324  10.92
# 4       2016/01/15 16:50:00  6.355300   99.27425   9.97   1.302  13.42
# ...                     ...       ...        ...    ...     ...    ...
# 348626  2018/02/20 14:00:00  1.951017  119.55690    NaN   6.792  11.18
# 348627  2018/02/20 14:10:00  2.108797  105.50730    NaN   7.276  11.65
# 348628  2018/02/20 14:20:00  1.950363   90.44153    NaN   7.355  11.79
# 348629  2018/02/20 14:30:00  2.812437  142.61050    NaN   9.820  17.94
# 348630  2018/02/20 14:40:00  2.707250  135.58970    NaN  10.370  19.29
#
#           PM10   PM2.5  Pressure   Temp     NO1            Date Time  Hour  \
# 0       131.10  56.570     843.0  22.97  22.440  2016-01-15 16:10:00    16
# 1       130.70  46.890     844.0  22.58  18.970  2016-01-15 16:20:00    16
# 2       141.30  51.600     843.0  22.84  15.760  2016-01-15 16:30:00    16
# 3       146.10  53.250     844.0  22.32  14.190  2016-01-15 16:40:00    16
# 4       146.40  51.610     844.0  21.94  15.790  2016-01-15 16:50:00    16
# ...        ...     ...       ...    ...     ...                  ...   ...
# 348626   10.14   0.074     848.0  26.51   4.990  2018-02-20 14:00:00    14
# 348627   14.31   0.098     848.0  26.74   4.888  2018-02-20 14:10:00    14
# 348628   16.97   0.094     848.0  27.15   4.922  2018-02-20 14:20:00    14
# 348629   25.48   0.110     847.0  26.81   8.500  2018-02-20 14:30:00    14
# 348630   33.08   0.125     847.0  26.30   9.350  2018-02-20 14:40:00    14
#
#         Month  DayOfWeek  Wind_lag1  Wind Dir_lag1  SO2_lag1  NO2_lag1  \
# 0           1          4        NaN            NaN       NaN       NaN
# 1           1          4   5.726794      101.24370     25.67     0.808
# 2           1          4   5.942719      101.66950     20.56     1.167
# 3           1          4   6.538234       94.81412     17.24     1.212
# 4           1          4   7.156286       91.86486     13.81     1.324
# ...       ...        ...        ...            ...       ...       ...
# 348626      2          1   2.756740      143.18480       NaN     8.390
# 348627      2          1   1.951017      119.55690       NaN     6.792
# 348628      2          1   2.108797      105.50730       NaN     7.276
# 348629      2          1   1.950363       90.44153       NaN     7.355
# 348630      2          1   2.812437      142.61050       NaN     9.820
#
#         NOX_lag1  PM10_lag1  PM2.5_lag1  Pressure_lag1  Temp_lag1  NO1_lag1  \
# 0            NaN        NaN         NaN            NaN        NaN       NaN
# 1          18.10     131.10      56.570          843.0      22.97    22.440
# 2          17.69     130.70      46.890          844.0      22.58    18.970
# 3          12.66     141.30      51.600          843.0      22.84    15.760
# 4          10.92     146.10      53.250          844.0      22.32    14.190
# ...          ...        ...         ...            ...        ...       ...
# 348626     15.27      19.42       0.110          848.0      26.35     7.310
# 348627     11.18      10.14       0.074          848.0      26.51     4.990
# 348628     11.65      14.31       0.098          848.0      26.74     4.888
# 348629     11.79      16.97       0.094          848.0      27.15     4.922
# 348630     17.94      25.48       0.110          847.0      26.81     8.500
#
#         Wind_roll3_mean  Wind_roll3_std  Wind_roll6_mean  Wind_roll6_std  \
# 0              5.726794             NaN         5.726794             NaN
# 1              5.834757        0.152682         5.834757        0.152682
# 2              6.069249        0.420257         6.069249        0.420257
# 3              6.545746        0.606818         6.341008        0.642772
# 4              6.683273        0.419728         6.343867        0.556694
# ...                 ...             ...              ...             ...
# 348626         2.463012        0.445003         2.633396        0.445193
# 348627         2.272185        0.426988         2.589677        0.487017
# 348628         2.003392        0.091284         2.367299        0.403726
# 348629         2.290532        0.458872         2.376772        0.415164
# 348630         2.490017        0.470304         2.381101        0.419091
#
#         Wind_roll12_mean  Wind_roll12_std  Wind_roll24_mean  Wind_roll24_std  \
# 0               5.726794              NaN          5.726794              NaN
# 1               5.834757         0.152682          5.834757         0.152682
# 2               6.069249         0.420257          6.069249         0.420257
# 3               6.341008         0.642772          6.341008         0.642772
# 4               6.343867         0.556694          6.343867         0.556694
# ...                  ...              ...               ...              ...
# 348626          2.657896         0.589414          2.671371         0.585077
# 348627          2.627135         0.608968          2.690958         0.556158
# 348628          2.667315         0.537231          2.704705         0.532104
# 348629          2.706733         0.528264          2.715199         0.531621
# 348630          2.684492         0.521558          2.728817         0.526837
#
#         Wind Dir_roll3_mean  Wind Dir_roll3_std  Wind Dir_roll6_mean  \
# 0                101.243700                 NaN           101.243700
# 1                101.456600            0.301086           101.456600
# 2                 99.242440            3.840943            99.242440
# 3                 96.116160            5.030330            97.398045
# 4                 95.317743            3.730280            97.773286
# ...                     ...                 ...                  ...
# 348626           139.529067           18.418439           142.810150
# 348627           122.749667           19.040584           139.182667
# 348628           105.168577           14.560640           128.382922
# 348629           112.853110           26.849042           126.191088
# 348630           122.880577           28.311512           122.815122
#
#         Wind Dir_roll6_std  Wind Dir_roll12_mean  Wind Dir_roll12_std  \
# 0                      NaN            101.243700                  NaN
# 1                 0.301086            101.456600             0.301086
# 2                 3.840943             99.242440             3.840943
# 3                 4.841735             97.398045             4.841735
# 4                 4.276193             97.773286             4.276193
# ...                    ...                   ...                  ...
# 348626           15.965218            148.888617            17.766822
# 348627           21.659011            144.760650            21.557200
# 348628           27.435806            139.608136            26.435877
# 348629           25.249277            136.748761            23.752348
# 348630           21.578678            133.377477            20.285842
#
#         Wind Dir_roll24_mean  Wind Dir_roll24_std  SO2_roll3_mean  \
# 0                 101.243700                  NaN       25.670000
# 1                 101.456600             0.301086       23.115000
# 2                  99.242440             3.840943       21.156667
# 3                  97.398045             4.841735       17.203333
# 4                  97.773286             4.276193       13.673333
# ...                      ...                  ...             ...
# 348626            141.452750            17.251660             NaN
# 348627            141.048708            17.990856             NaN
# 348628            140.441164            19.447564             NaN
# 348629            140.815068            19.397254             NaN
# 348630            140.976660            19.334169             NaN
#
#         SO2_roll3_std  SO2_roll6_mean  SO2_roll6_std  SO2_roll12_mean  \
# 0                 NaN       25.670000            NaN        25.670000
# 1            3.613316       23.115000       3.613316        23.115000
# 2            4.246555       21.156667       4.246555        21.156667
# 3            3.375149       19.320000       5.051290        19.320000
# 4            3.636926       17.450000       6.051541        17.450000
# ...               ...             ...            ...              ...
# 348626            NaN             NaN            NaN              NaN
# 348627            NaN             NaN            NaN              NaN
# 348628            NaN             NaN            NaN              NaN
# 348629            NaN             NaN            NaN              NaN
# 348630            NaN             NaN            NaN              NaN
#
#         SO2_roll12_std  SO2_roll24_mean  SO2_roll24_std  NO2_roll3_mean  \
# 0                  NaN        25.670000             NaN        0.808000
# 1             3.613316        23.115000        3.613316        0.987500
# 2             4.246555        21.156667        4.246555        1.062333
# 3             5.051290        19.320000        5.051290        1.234333
# 4             6.051541        17.450000        6.051541        1.279333
# ...                ...              ...             ...             ...
# 348626             NaN              NaN             NaN        7.787333
# 348627             NaN              NaN             NaN        7.486000
# 348628             NaN              NaN             NaN        7.141000
# 348629             NaN              NaN             NaN        8.150333
# 348630             NaN              NaN             NaN        9.181667
#
#         NO2_roll3_std  NO2_roll6_mean  NO2_roll6_std  NO2_roll12_mean  \
# 0                 NaN        0.808000            NaN         0.808000
# 1            0.253851        0.987500       0.253851         0.987500
# 2            0.221405        1.062333       0.221405         1.062333
# 3            0.080848        1.127750       0.223154         1.127750
# 4            0.059341        1.162600       0.208377         1.162600
# ...               ...             ...            ...              ...
# 348626       0.868356        8.713667       1.204827         9.097583
# 348627       0.819436        8.223000       1.059374         8.835583
# 348628       0.304813        7.927167       1.001702         8.703500
# 348629       1.446513        7.968833       1.085407         8.868583
# 348630       1.605664        8.333833       1.470524         8.927750
#
#         NO2_roll12_std  NO2_roll24_mean  NO2_roll24_std  NOX_roll3_mean  \
# 0                  NaN         0.808000             NaN       18.100000
# 1             0.253851         0.987500        0.253851       17.895000
# 2             0.221405         1.062333        0.221405       16.150000
# 3             0.223154         1.127750        0.223154       13.756667
# 4             0.208377         1.162600        0.208377       12.333333
# ...                ...              ...             ...             ...
# 348626        1.109534        12.335042        3.592860       14.060000
# 348627        1.139672        12.001125        3.677694       12.700000
# 348628        1.215777        11.568833        3.583576       11.540000
# 348629        1.222197        11.205500        3.274801       13.793333
# 348630        1.279820        10.907167        2.987089       16.340000
#
#         NOX_roll3_std  NOX_roll6_mean  NOX_roll6_std  NOX_roll12_mean  \
# 0                 NaN       18.100000            NaN        18.100000
# 1            0.289914       17.895000       0.289914        17.895000
# 2            3.029373       16.150000       3.029373        16.150000
# 3            3.515712       14.842500       3.599485        14.842500
# 4            1.281614       14.558000       3.181497        14.558000
# ...               ...             ...            ...              ...
# 348626       2.504736       16.156667       2.949059        16.924167
# 348627       2.238057       14.905000       3.012466        16.288333
# 348628       0.319531       14.118333       3.123744        15.843333
# 348629       3.591801       13.926667       2.773306        16.190000
# 348630       3.997812       14.520000       3.517306        16.229167
#
#         NOX_roll12_std  NOX_roll24_mean  NOX_roll24_std  PM10_roll3_mean  \
# 0                  NaN        18.100000             NaN       131.100000
# 1             0.289914        17.895000        0.289914       130.900000
# 2             3.029373        16.150000        3.029373       134.366667
# 3             3.599485        14.842500        3.599485       139.366667
# 4             3.181497        14.558000        3.181497       144.600000
# ...                ...              ...             ...              ...
# 348626        2.601347        26.232083       10.607023        17.286667
# 348627        2.889677        25.335417       10.900562        14.623333
# 348628        3.147912        24.097500       10.669578        13.806667
# 348629        3.129034        23.040417        9.913307        18.920000
# 348630        3.167650        22.081667        9.044257        25.176667
#
#         PM10_roll3_std  PM10_roll6_mean  PM10_roll6_std  PM10_roll12_mean  \
# 0                  NaN       131.100000             NaN        131.100000
# 1             0.282843       130.900000        0.282843        130.900000
# 2             6.007773       134.366667        6.007773        134.366667
# 3             7.879932       137.300000        7.647222        137.300000
# 4             2.861818       139.120000        7.773159        139.120000
# ...                ...              ...             ...               ...
# 348626        6.354505        20.556667        5.941935         21.910000
# 348627        4.647928        19.693333        6.479876         21.445833
# 348628        3.442707        18.406667        6.040873         20.900000
# 348629        5.834732        18.103333        5.529002         20.504167
# 348630        8.059282        19.900000        8.248270         21.048333
#
#         PM10_roll12_std  PM10_roll24_mean  PM10_roll24_std  PM2.5_roll3_mean  \
# 0                   NaN        131.100000              NaN         56.570000
# 1              0.282843        130.900000         0.282843         51.730000
# 2              6.007773        134.366667         6.007773         51.686667
# 3              7.647222        137.300000         7.647222         50.580000
# 4              7.773159        139.120000         7.773159         52.153333
# ...                 ...               ...              ...               ...
# 348626         5.334246         20.590042         7.907021          0.092000
# 348627         5.752862         21.034667         7.178892          0.094000
# 348628         5.848119         21.409583         6.685006          0.088667
# 348629         5.293673         21.771250         6.659529          0.100667
# 348630         6.225306         22.017500         6.969875          0.109667
#
#         PM2.5_roll3_std  PM2.5_roll6_mean  PM2.5_roll6_std  PM2.5_roll12_mean  \
# 0                   NaN         56.570000              NaN          56.570000
# 1              6.844794         51.730000         6.844794          51.730000
# 2              4.840582         51.686667         4.840582          51.686667
# 3              3.300409         52.077500         4.028874          52.077500
# 4              0.949754         51.984000         3.495366          51.984000
# ...                 ...               ...              ...                ...
# 348626         0.018000          0.088167         0.012937           0.093000
# 348627         0.018330          0.090667         0.013186           0.092417
# 348628         0.012858          0.091000         0.013251           0.094500
# 348629         0.008327          0.096333         0.013411           0.094167
# 348630         0.015503          0.101833         0.017440           0.099000
#
#         PM2.5_roll12_std  PM2.5_roll24_mean  PM2.5_roll24_std  \
# 0                    NaN          56.570000               NaN
# 1               6.844794          51.730000          6.844794
# 2               4.840582          51.686667          4.840582
# 3               4.028874          52.077500          4.028874
# 4               3.495366          51.984000          3.495366
# ...                  ...                ...               ...
# 348626          0.020271           0.095208          0.018629
# 348627          0.019993           0.093875          0.017114
# 348628          0.018584           0.093333          0.016885
# 348629          0.018235           0.094917          0.016576
# 348630          0.018066           0.096875          0.017253
#
#         Pressure_roll3_mean  Pressure_roll3_std  Pressure_roll6_mean  \
# 0                843.000000                 NaN           843.000000
# 1                843.500000            0.707107           843.500000
# 2                843.333333            0.577350           843.333333
# 3                843.666667            0.577350           843.500000
# 4                843.666667            0.577350           843.600000
# ...                     ...                 ...                  ...
# 348626           848.000000            0.000000           848.000000
# 348627           848.000000            0.000000           848.000000
# 348628           848.000000            0.000000           848.000000
# 348629           847.666667            0.577350           847.833333
# 348630           847.333333            0.577350           847.666667
#
#         Pressure_roll6_std  Pressure_roll12_mean  Pressure_roll12_std  \
# 0                      NaN            843.000000                  NaN
# 1                 0.707107            843.500000             0.707107
# 2                 0.577350            843.333333             0.577350
# 3                 0.577350            843.500000             0.577350
# 4                 0.547723            843.600000             0.547723
# ...                    ...                   ...                  ...
# 348626            0.000000            848.416667             0.514929
# 348627            0.000000            848.333333             0.492366
# 348628            0.000000            848.250000             0.452267
# 348629            0.408248            848.083333             0.514929
# 348630            0.516398            847.916667             0.514929
#
#         Pressure_roll24_mean  Pressure_roll24_std  Temp_roll3_mean  \
# 0                 843.000000                  NaN        22.970000
# 1                 843.500000             0.707107        22.775000
# 2                 843.333333             0.577350        22.796667
# 3                 843.500000             0.577350        22.580000
# 4                 843.600000             0.547723        22.366667
# ...                      ...                  ...              ...
# 348626            849.041667             0.806450        26.403333
# 348627            848.958333             0.806450        26.533333
# 348628            848.875000             0.797414        26.800000
# 348629            848.750000             0.846990        26.900000
# 348630            848.625000             0.875388        26.753333
#
#         Temp_roll3_std  Temp_roll6_mean  Temp_roll6_std  Temp_roll12_mean  \
# 0                  NaN        22.970000             NaN         22.970000
# 1             0.275772        22.775000        0.275772         22.775000
# 2             0.198578        22.796667        0.198578         22.796667
# 3             0.260000        22.677500        0.288256         22.677500
# 4             0.451811        22.530000        0.413642         22.530000
# ...                ...              ...             ...               ...
# 348626        0.092376        26.176667        0.279976         25.552500
# 348627        0.196044        26.343333        0.265305         25.790000
# 348628        0.324191        26.528333        0.375575         25.992500
# 348629        0.219317        26.651667        0.310897         26.133333
# 348630        0.427824        26.643333        0.321102         26.217500
#
#         Temp_roll12_std  Temp_roll24_mean  Temp_roll24_std  NO1_roll3_mean  \
# 0                   NaN         22.970000              NaN       22.440000
# 1              0.275772         22.775000         0.275772       20.705000
# 2              0.198578         22.796667         0.198578       19.056667
# 3              0.288256         22.677500         0.288256       16.306667
# 4              0.413642         22.530000         0.413642       15.246667
# ...                 ...               ...              ...             ...
# 348626         0.776848         24.439583         1.328142        6.716667
# 348627         0.647218         24.618750         1.336678        5.729333
# 348628         0.661982         24.804167         1.367238        4.933333
# 348629         0.638853         24.979583         1.341986        6.103333
# 348630         0.581614         25.133750         1.267177        7.590667
#
#         NO1_roll3_std  NO1_roll6_mean  NO1_roll6_std  NO1_roll12_mean  \
# 0                 NaN       22.440000            NaN        22.440000
# 1            2.453661       20.705000       2.453661        20.705000
# 2            3.340843       19.056667       3.340843        19.056667
# 3            2.436439       17.840000       3.655398        17.840000
# 4            0.915223       17.430000       3.295747        17.430000
# ...               ...             ...            ...              ...
# 348626       1.519517        7.906667       1.767141         8.262917
# 348627       1.369847        7.149667       1.947688         7.898583
# 348628       0.051936        6.661667       2.098124         7.591250
# 348629       2.075644        6.410000       1.661248         7.775833
# 348630       2.349885        6.660000       1.999686         7.762500
#
#         NO1_roll12_std  NO1_roll24_mean  NO1_roll24_std  \
# 0                  NaN        22.440000             NaN
# 1             2.453661        20.705000        2.453661
# 2             3.340843        19.056667        3.340843
# 3             3.655398        17.840000        3.655398
# 4             3.295747        17.430000        3.295747
# ...                ...              ...             ...
# 348626        1.540337        14.330208        7.095501
# 348627        1.781267        13.770958        7.294344
# 348628        1.956865        12.968958        7.158147
# 348629        1.926684        12.276042        6.721335
# 348630        1.914104        11.619375        6.159327
#
#         Location_Chicken Farm  Location_Marapong  Location_Phola  \
# 0                        True              False           False
# 1                        True              False           False
# 2                        True              False           False
# 3                        True              False           False
# 4                        True              False           False
# ...                       ...                ...             ...
# 348626                  False              False            True
# 348627                  False              False            True
# 348628                  False              False            True
# 348629                  False              False            True
# 348630                  False              False            True
#
#         Season_Autumn  Season_Spring  Season_Summer  Season_Winter  \
# 0               False          False           True          False
# 1               False          False           True          False
# 2               False          False           True          False
# 3               False          False           True          False
# 4               False          False           True          False
# ...               ...            ...            ...            ...
# 348626          False          False           True          False
# 348627          False          False           True          False
# 348628          False          False           True          False
# 348629          False          False           True          False
# 348630          False          False           True          False
#
#         DayType_Weekday  DayType_Weekend
# 0                  True            False
# 1                  True            False
# 2                  True            False
# 3                  True            False
# 4                  True            False
# ...                 ...              ...
# 348626             True            False
# 348627             True            False
# 348628             True            False
# 348629             True            False
# 348630             True            False
#
# [348631 rows x 114 columns]

# %%
# Shift the target by -24 to predict 24 hours ahead
data_for_model['PM2.5_t+12'] = data_for_model['PM2.5'].shift(-12)

# Drop rows with NaNs introduced by shifting
data_for_model = data_for_model.dropna(subset=['PM2.5_t+12'])

data_for_model
# Out:
#                        Date      Wind   Wind Dir    SO2     NO2    NOX  \
# 0       2016/01/15 16:10:00  5.726794  101.24370  25.67   0.808  18.10
# 1       2016/01/15 16:20:00  5.942719  101.66950  20.56   1.167  17.69
# 2       2016/01/15 16:30:00  6.538234   94.81412  17.24   1.212  12.66
# 3       2016/01/15 16:40:00  7.156286   91.86486  13.81   1.324  10.92
# 4       2016/01/15 16:50:00  6.355300   99.27425   9.97   1.302  13.42
# ...                     ...       ...        ...    ...     ...    ...
# 348614  2018/02/20 12:00:00  2.353307  150.79790    NaN  13.670  26.09
# 348615  2018/02/20 12:10:00  2.477931  155.04290    NaN  10.420  19.28
# 348616  2018/02/20 12:20:00  1.468203  152.27170    NaN   8.940  17.13
# 348617  2018/02/20 12:30:00  2.339423  176.92300    NaN   7.839  13.78
# 348618  2018/02/20 12:40:00  2.974136  176.04510    NaN   9.660  18.82
#
#           PM10   PM2.5  Pressure   Temp     NO1            Date Time  Hour  \
# 0       131.10  56.570     843.0  22.97  22.440  2016-01-15 16:10:00    16
# 1       130.70  46.890     844.0  22.58  18.970  2016-01-15 16:20:00    16
# 2       141.30  51.600     843.0  22.84  15.760  2016-01-15 16:30:00    16
# 3       146.10  53.250     844.0  22.32  14.190  2016-01-15 16:40:00    16
# 4       146.40  51.610     844.0  21.94  15.790  2016-01-15 16:50:00    16
# ...        ...     ...       ...    ...     ...                  ...   ...
# 348614   17.05   0.098     849.0  23.46  12.890  2018-02-20 12:00:00    12
# 348615   19.88   0.105     849.0  23.89   9.260  2018-02-20 12:10:00    12
# 348616   23.52   0.069     849.0  24.72   8.610  2018-02-20 12:20:00    12
# 348617   30.23   0.114     849.0  25.12   6.285  2018-02-20 12:30:00    12
# 348618   26.55   0.067     849.0  25.29   9.510  2018-02-20 12:40:00    12
#
#         Month  DayOfWeek  Wind_lag1  Wind Dir_lag1  SO2_lag1  NO2_lag1  \
# 0           1          4        NaN            NaN       NaN       NaN
# 1           1          4   5.726794      101.24370     25.67     0.808
# 2           1          4   5.942719      101.66950     20.56     1.167
# 3           1          4   6.538234       94.81412     17.24     1.212
# 4           1          4   7.156286       91.86486     13.81     1.324
# ...       ...        ...        ...            ...       ...       ...
# 348614      2          1   2.760334      141.77670       NaN    14.000
# 348615      2          1   2.353307      150.79790       NaN    13.670
# 348616      2          1   2.477931      155.04290       NaN    10.420
# 348617      2          1   1.468203      152.27170       NaN     8.940
# 348618      2          1   2.339423      176.92300       NaN     7.839
#
#         NOX_lag1  PM10_lag1  PM2.5_lag1  Pressure_lag1  Temp_lag1  NO1_lag1  \
# 0            NaN        NaN         NaN            NaN        NaN       NaN
# 1          18.10     131.10      56.570          843.0      22.97    22.440
# 2          17.69     130.70      46.890          844.0      22.58    18.970
# 3          12.66     141.30      51.600          843.0      22.84    15.760
# 4          10.92     146.10      53.250          844.0      22.32    14.190
# ...          ...        ...         ...            ...        ...       ...
# 348614     26.65      13.56       0.081          849.0      23.47    13.110
# 348615     26.09      17.05       0.098          849.0      23.46    12.890
# 348616     19.28      19.88       0.105          849.0      23.89     9.260
# 348617     17.13      23.52       0.069          849.0      24.72     8.610
# 348618     13.78      30.23       0.114          849.0      25.12     6.285
#
#         Wind_roll3_mean  Wind_roll3_std  Wind_roll6_mean  Wind_roll6_std  \
# 0              5.726794             NaN         5.726794             NaN
# 1              5.834757        0.152682         5.834757        0.152682
# 2              6.069249        0.420257         6.069249        0.420257
# 3              6.545746        0.606818         6.341008        0.642772
# 4              6.683273        0.419728         6.343867        0.556694
# ...                 ...             ...              ...             ...
# 348614         2.717377        0.344605         2.982793        0.371461
# 348615         2.530524        0.208548         2.864404        0.404596
# 348616         2.099814        0.550529         2.544352        0.612956
# 348617         2.095186        0.547382         2.406281        0.532436
# 348618         2.260587        0.756055         2.395556        0.517595
#
#         Wind_roll12_mean  Wind_roll12_std  Wind_roll24_mean  Wind_roll24_std  \
# 0               5.726794              NaN          5.726794              NaN
# 1               5.834757         0.152682          5.834757         0.152682
# 2               6.069249         0.420257          6.069249         0.420257
# 3               6.341008         0.642772          6.341008         0.642772
# 4               6.343867         0.556694          6.343867         0.556694
# ...                  ...              ...               ...              ...
# 348614          2.684846         0.606585          2.680321         0.579210
# 348615          2.754780         0.516734          2.633716         0.546359
# 348616          2.742095         0.548034          2.549021         0.563374
# 348617          2.723665         0.558315          2.508024         0.539887
# 348618          2.773142         0.551396          2.513115         0.543832
#
#         Wind Dir_roll3_mean  Wind Dir_roll3_std  Wind Dir_roll6_mean  \
# 0                101.243700                 NaN           101.243700
# 1                101.456600            0.301086           101.456600
# 2                 99.242440            3.840943            99.242440
# 3                 96.116160            5.030330            97.398045
# 4                 95.317743            3.730280            97.773286
# ...                     ...                 ...                  ...
# 348614           143.525000            6.575440           142.649683
# 348615           149.205833            6.774882           145.155667
# 348616           152.704167            2.155290           145.395967
# 348617           161.412533           13.503734           152.468767
# 348618           168.413267           13.985897           158.809550
#
#         Wind Dir_roll6_std  Wind Dir_roll12_mean  Wind Dir_roll12_std  \
# 0                      NaN            101.243700                  NaN
# 1                 0.301086            101.456600             0.301086
# 2                 3.840943             99.242440             3.840943
# 3                 4.841735             97.398045             4.841735
# 4                 4.276193             97.773286             4.276193
# ...                    ...                   ...                  ...
# 348614            6.772201            134.016883            13.638129
# 348615            8.224863            137.336767            13.490417
# 348616            8.441995            141.274192             9.509382
# 348617           13.646393            144.881375            13.655097
# 348618           14.397200            148.575842            15.623472
#
#         Wind Dir_roll24_mean  Wind Dir_roll24_std  SO2_roll3_mean  \
# 0                 101.243700                  NaN       25.670000
# 1                 101.456600             0.301086       23.115000
# 2                  99.242440             3.840943       21.156667
# 3                  97.398045             4.841735       17.203333
# 4                  97.773286             4.276193       13.673333
# ...                      ...                  ...             ...
# 348614            128.028083            13.431400             NaN
# 348615            128.591121            14.278515             NaN
# 348616            129.641550            15.066658             NaN
# 348617            131.938033            17.777227             NaN
# 348618            134.085367            19.834385             NaN
#
#         SO2_roll3_std  SO2_roll6_mean  SO2_roll6_std  SO2_roll12_mean  \
# 0                 NaN       25.670000            NaN        25.670000
# 1            3.613316       23.115000       3.613316        23.115000
# 2            4.246555       21.156667       4.246555        21.156667
# 3            3.375149       19.320000       5.051290        19.320000
# 4            3.636926       17.450000       6.051541        17.450000
# ...               ...             ...            ...              ...
# 348614            NaN             NaN            NaN              NaN
# 348615            NaN             NaN            NaN              NaN
# 348616            NaN             NaN            NaN              NaN
# 348617            NaN             NaN            NaN              NaN
# 348618            NaN             NaN            NaN              NaN
#
#         SO2_roll12_std  SO2_roll24_mean  SO2_roll24_std  NO2_roll3_mean  \
# 0                  NaN        25.670000             NaN        0.808000
# 1             3.613316        23.115000        3.613316        0.987500
# 2             4.246555        21.156667        4.246555        1.062333
# 3             5.051290        19.320000        5.051290        1.234333
# 4             6.051541        17.450000        6.051541        1.279333
# ...                ...              ...             ...             ...
# 348614             NaN              NaN             NaN       13.796667
# 348615             NaN              NaN             NaN       12.696667
# 348616             NaN              NaN             NaN       11.010000
# 348617             NaN              NaN             NaN        9.066333
# 348618             NaN              NaN             NaN        8.813000
#
#         NO2_roll3_std  NO2_roll6_mean  NO2_roll6_std  NO2_roll12_mean  \
# 0                 NaN        0.808000            NaN         0.808000
# 1            0.253851        0.987500       0.253851         0.987500
# 2            0.221405        1.062333       0.221405         1.062333
# 3            0.080848        1.127750       0.223154         1.127750
# 4            0.059341        1.162600       0.208377         1.162600
# ...               ...             ...            ...              ...
# 348614       0.177858       14.303333       0.932066        15.572500
# 348615       1.978543       13.380000       1.520802        15.166667
# 348616       2.419566       12.395000       2.158497        14.434167
# 348617       1.295129       11.431500       2.719635        13.542417
# 348618       0.917119       10.754833       2.535184        12.886583
#
#         NO2_roll12_std  NO2_roll24_mean  NO2_roll24_std  NOX_roll3_mean  \
# 0                  NaN         0.808000             NaN       18.100000
# 1             0.253851         0.987500        0.253851       17.895000
# 2             0.221405         1.062333        0.221405       16.150000
# 3             0.223154         1.127750        0.223154       13.756667
# 4             0.208377         1.162600        0.208377       12.333333
# ...                ...              ...             ...             ...
# 348614        1.700530        14.449875        2.402913       27.210000
# 348615        2.262377        14.577500        2.067784       24.006667
# 348616        2.731365        14.431667        2.331672       20.833333
# 348617        3.002418        14.168708        2.692730       16.730000
# 348618        2.910335        14.075792        2.810671       16.576667
#
#         NOX_roll3_std  NOX_roll6_mean  NOX_roll6_std  NOX_roll12_mean  \
# 0                 NaN       18.100000            NaN        18.100000
# 1            0.289914       17.895000       0.289914        17.895000
# 2            3.029373       16.150000       3.029373        16.150000
# 3            3.515712       14.842500       3.599485        14.842500
# 4            1.281614       14.558000       3.181497        14.558000
# ...               ...             ...            ...              ...
# 348614       1.481621       30.853333       4.480043        35.540000
# 348615       4.102979       27.905000       5.380081        34.382500
# 348616       4.677610       24.901667       5.553681        32.351667
# 348617       2.771732       21.970000       6.074553        29.890833
# 348618       2.565158       20.291667       5.091881        27.934167
#
#         NOX_roll12_std  NOX_roll24_mean  NOX_roll24_std  PM10_roll3_mean  \
# 0                  NaN        18.100000             NaN       131.100000
# 1             0.289914        17.895000        0.289914       130.900000
# 2             3.029373        16.150000        3.029373       134.366667
# 3             3.599485        14.842500        3.599485       139.366667
# 4             3.181497        14.558000        3.181497       144.600000
# ...                ...              ...             ...              ...
# 348614        6.281088        34.878333        7.341147        14.583333
# 348615        7.843155        34.992083        7.060594        16.830000
# 348616        8.914566        34.350000        7.939288        20.150000
# 348617        9.659276        33.401667        8.960026        24.543333
# 348618        9.288072        32.962083        9.413728        26.766667
#
#         PM10_roll3_std  PM10_roll6_mean  PM10_roll6_std  PM10_roll12_mean  \
# 0                  NaN       131.100000             NaN        131.100000
# 1             0.282843       130.900000        0.282843        130.900000
# 2             6.007773       134.366667        6.007773        134.366667
# 3             7.879932       137.300000        7.647222        137.300000
# 4             2.861818       139.120000        7.773159        139.120000
# ...                ...              ...             ...               ...
# 348614        2.146493        17.570000        4.949703         19.270083
# 348615        3.165738        16.408333        2.593017         20.623500
# 348616        3.243440        17.356667        3.918605         21.919167
# 348617        5.250336        19.563333        6.529155         23.038333
# 348618        3.360243        21.798333        6.176282         22.986667
#
#         PM10_roll12_std  PM10_roll24_mean  PM10_roll24_std  PM2.5_roll3_mean  \
# 0                   NaN        131.100000              NaN         56.570000
# 1              0.282843        130.900000         0.282843         51.730000
# 2              6.007773        134.366667         6.007773         51.686667
# 3              7.647222        137.300000         7.647222         50.580000
# 4              7.773159        139.120000         7.773159         52.153333
# ...                 ...               ...              ...               ...
# 348614         9.923213         17.912333        12.249182          0.090333
# 348615         8.619386         17.782750        12.209516          0.094667
# 348616         7.659909         18.753500        11.666716          0.090667
# 348617         7.823333         20.009917        11.181423          0.096000
# 348618         7.795564         20.835000        10.886995          0.083333
#
#         PM2.5_roll3_std  PM2.5_roll6_mean  PM2.5_roll6_std  PM2.5_roll12_mean  \
# 0                   NaN         56.570000              NaN          56.570000
# 1              6.844794         51.730000         6.844794          51.730000
# 2              4.840582         51.686667         4.840582          51.686667
# 3              3.300409         52.077500         4.028874          52.077500
# 4              0.949754         51.984000         3.495366          51.984000
# ...                 ...               ...              ...                ...
# 348614         0.008622          0.092000         0.007014           0.097417
# 348615         0.012342          0.094500         0.008643           0.095333
# 348616         0.019088          0.091000         0.013638           0.092167
# 348617         0.023812          0.093167         0.016315           0.095667
# 348618         0.026577          0.089000         0.019545           0.094750
#
#         PM2.5_roll12_std  PM2.5_roll24_mean  PM2.5_roll24_std  \
# 0                    NaN          56.570000               NaN
# 1               6.844794          51.730000          6.844794
# 2               4.840582          51.686667          4.840582
# 3               4.028874          52.077500          4.028874
# 4               3.495366          51.984000          3.495366
# ...                  ...                ...               ...
# 348614          0.017438           0.100958          0.020138
# 348615          0.014424           0.100875          0.020116
# 348616          0.015741           0.099667          0.021141
# 348617          0.015517           0.100875          0.021095
# 348618          0.016918           0.099292          0.022170
#
#         Pressure_roll3_mean  Pressure_roll3_std  Pressure_roll6_mean  \
# 0                843.000000                 NaN           843.000000
# 1                843.500000            0.707107           843.500000
# 2                843.333333            0.577350           843.333333
# 3                843.666667            0.577350           843.500000
# 4                843.666667            0.577350           843.600000
# ...                     ...                 ...                  ...
# 348614           849.000000            0.000000           849.333333
# 348615           849.000000            0.000000           849.166667
# 348616           849.000000            0.000000           849.000000
# 348617           849.000000            0.000000           849.000000
# 348618           849.000000            0.000000           849.000000
#
#         Pressure_roll6_std  Pressure_roll12_mean  Pressure_roll12_std  \
# 0                      NaN            843.000000                  NaN
# 1                 0.707107            843.500000             0.707107
# 2                 0.577350            843.333333             0.577350
# 3                 0.577350            843.500000             0.577350
# 4                 0.547723            843.600000             0.547723
# ...                    ...                   ...                  ...
# 348614            0.516398            849.666667             0.492366
# 348615            0.408248            849.583333             0.514929
# 348616            0.000000            849.500000             0.522233
# 348617            0.000000            849.416667             0.514929
# 348618            0.000000            849.333333             0.492366
#
#         Pressure_roll24_mean  Pressure_roll24_std  Temp_roll3_mean  \
# 0                 843.000000                  NaN        22.970000
# 1                 843.500000             0.707107        22.775000
# 2                 843.333333             0.577350        22.796667
# 3                 843.500000             0.577350        22.580000
# 4                 843.600000             0.547723        22.366667
# ...                      ...                  ...              ...
# 348614            850.000000             0.589768        23.616667
# 348615            849.916667             0.583592        23.606667
# 348616            849.833333             0.564660        24.023333
# 348617            849.791667             0.588230        24.576667
# 348618            849.708333             0.550033        25.043333
#
#         Temp_roll3_std  Temp_roll6_mean  Temp_roll6_std  Temp_roll12_mean  \
# 0                  NaN        22.970000             NaN         22.970000
# 1             0.275772        22.775000        0.275772         22.775000
# 2             0.198578        22.796667        0.198578         22.796667
# 3             0.260000        22.677500        0.288256         22.677500
# 4             0.451811        22.530000        0.413642         22.530000
# ...                ...              ...             ...               ...
# 348614        0.262742        23.715000        0.266139         23.326667
# 348615        0.245425        23.705000        0.256496         23.447500
# 348616        0.640495        23.910000        0.460608         23.615833
# 348617        0.627402        24.096667        0.679372         23.825833
# 348618        0.292632        24.325000        0.823134         24.050000
#
#         Temp_roll12_std  Temp_roll24_mean  Temp_roll24_std  NO1_roll3_mean  \
# 0                   NaN         22.970000              NaN       22.440000
# 1              0.275772         22.775000         0.275772       20.705000
# 2              0.198578         22.796667         0.198578       19.056667
# 3              0.288256         22.677500         0.288256       16.306667
# 4              0.413642         22.530000         0.413642       15.246667
# ...                 ...               ...              ...             ...
# 348614         0.618405         22.328750         1.338290       13.850000
# 348615         0.569100         22.499583         1.259491       11.753333
# 348616         0.623997         22.699583         1.212279       10.253333
# 348617         0.673153         22.908333         1.177838        8.051667
# 348618         0.675722         23.103333         1.168152        8.135000
#
#         NO1_roll3_std  NO1_roll6_mean  NO1_roll6_std  NO1_roll12_mean  \
# 0                 NaN       22.440000            NaN        22.440000
# 1            2.453661       20.705000       2.453661        20.705000
# 2            3.340843       19.056667       3.340843        19.056667
# 3            2.436439       17.840000       3.655398        17.840000
# 4            0.915223       17.430000       3.295747        17.430000
# ...               ...             ...            ...              ...
# 348614       1.476347       17.000000       3.730496        20.397500
# 348615       2.162090       14.965000       4.114908        19.643333
# 348616       2.306433       12.945000       3.669625        18.346667
# 348617       1.564116       10.950833       3.454942        16.776250
# 348618       1.664144        9.944167       2.627795        15.476250
#
#         NO1_roll12_std  NO1_roll24_mean  NO1_roll24_std  \
# 0                  NaN        22.440000             NaN
# 1             2.453661        20.705000        2.453661
# 2             3.340843        19.056667        3.340843
# 3             3.655398        17.840000        3.655398
# 4             3.295747        17.430000        3.295747
# ...                ...              ...             ...
# 348614        4.751779        20.870417        5.380484
# 348615        5.730576        20.855417        5.413612
# 348616        6.341079        20.355417        5.963496
# 348617        6.823607        19.662708        6.586845
# 348618        6.572980        19.309792        6.900368
#
#         Location_Chicken Farm  Location_Marapong  Location_Phola  \
# 0                        True              False           False
# 1                        True              False           False
# 2                        True              False           False
# 3                        True              False           False
# 4                        True              False           False
# ...                       ...                ...             ...
# 348614                  False              False            True
# 348615                  False              False            True
# 348616                  False              False            True
# 348617                  False              False            True
# 348618                  False              False            True
#
#         Season_Autumn  Season_Spring  Season_Summer  Season_Winter  \
# 0               False          False           True          False
# 1               False          False           True          False
# 2               False          False           True          False
# 3               False          False           True          False
# 4               False          False           True          False
# ...               ...            ...            ...            ...
# 348614          False          False           True          False
# 348615          False          False           True          False
# 348616          False          False           True          False
# 348617          False          False           True          False
# 348618          False          False           True          False
#
#         DayType_Weekday  DayType_Weekend  PM2.5_t+12
# 0                  True            False      47.750
# 1                  True            False      53.150
# 2                  True            False      62.480
# 3                  True            False      65.580
# 4                  True            False      62.070
# ...                 ...              ...         ...
# 348614             True            False       0.074
# 348615             True            False       0.098
# 348616             True            False       0.094
# 348617             True            False       0.110
# 348618             True            False       0.125
#
# [348619 rows x 115 columns]

# %%
location_cols = [col for col in data_for_model.columns if col.startswith('Location_')]

def decode_location(row):
    for col in location_cols:
        if row[col] == 1:
            return col.replace('Location_', '')
    return 'Unknown'

data_for_model['Location'] = data_for_model.apply(decode_location, axis=1)


data_for_model['Date Time'] = pd.to_datetime(data_for_model['Date Time'])
locations = data_for_model['Location'].unique()
# Out:
# C:\Users\Shivm\AppData\Local\Temp\ipykernel_22204\975132283.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_for_model['Location'] = data_for_model.apply(decode_location, axis=1)
# C:\Users\Shivm\AppData\Local\Temp\ipykernel_22204\975132283.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_for_model['Date Time'] = pd.to_datetime(data_for_model['Date Time'])

# %%
features_to_keep = [
    'Hour', 'Month', 'DayOfWeek', 'Date Time',

    'Wind', 'Wind_lag1', 'Wind_roll3_mean', 'Wind_roll6_mean', 'Wind_roll12_mean', 'Wind_roll24_mean',
    'Pressure', 'Pressure_lag1', 'Pressure_roll3_mean', 'Pressure_roll6_mean', 'Pressure_roll12_mean', 'Pressure_roll24_mean',
    'Temp', 'Temp_lag1', 'Temp_roll3_mean', 'Temp_roll6_mean', 'Temp_roll12_mean', 'Temp_roll24_mean',
    
    'SO2', 'SO2_lag1', 'SO2_roll3_mean', 'SO2_roll6_mean', 'SO2_roll12_mean', 'SO2_roll24_mean',
    'NO2', 'NO2_lag1', 'NO2_roll3_mean', 'NO2_roll6_mean', 'NO2_roll12_mean', 'NO2_roll24_mean',
    'NOX', 'NOX_lag1', 'NOX_roll3_mean', 'NOX_roll6_mean', 'NOX_roll12_mean', 'NOX_roll24_mean',
    'PM10', 'PM10_lag1', 'PM10_roll3_mean', 'PM10_roll6_mean', 'PM10_roll12_mean', 'PM10_roll24_mean',
    'PM2.5', 'PM2.5_t+12', 'PM2.5_lag1', 'PM2.5_roll3_mean', 'PM2.5_roll6_mean', 'PM2.5_roll12_mean', 'PM2.5_roll24_mean',

    'Location_Chicken Farm', 'Location_Marapong', 'Location_Phola',  # if using one-hot
    'Season_Autumn', 'Season_Spring', 'Season_Summer', 'Season_Winter',  # only if proven useful
]

data_for_model= data_for_model[features_to_keep]
data_for_model
# Out:
#         Hour  Month  DayOfWeek           Date Time      Wind  Wind_lag1  \
# 0         16      1          4 2016-01-15 16:10:00  5.726794        NaN
# 1         16      1          4 2016-01-15 16:20:00  5.942719   5.726794
# 2         16      1          4 2016-01-15 16:30:00  6.538234   5.942719
# 3         16      1          4 2016-01-15 16:40:00  7.156286   6.538234
# 4         16      1          4 2016-01-15 16:50:00  6.355300   7.156286
# ...      ...    ...        ...                 ...       ...        ...
# 348614    12      2          1 2018-02-20 12:00:00  2.353307   2.760334
# 348615    12      2          1 2018-02-20 12:10:00  2.477931   2.353307
# 348616    12      2          1 2018-02-20 12:20:00  1.468203   2.477931
# 348617    12      2          1 2018-02-20 12:30:00  2.339423   1.468203
# 348618    12      2          1 2018-02-20 12:40:00  2.974136   2.339423
#
#         Wind_roll3_mean  Wind_roll6_mean  Wind_roll12_mean  Wind_roll24_mean  \
# 0              5.726794         5.726794          5.726794          5.726794
# 1              5.834757         5.834757          5.834757          5.834757
# 2              6.069249         6.069249          6.069249          6.069249
# 3              6.545746         6.341008          6.341008          6.341008
# 4              6.683273         6.343867          6.343867          6.343867
# ...                 ...              ...               ...               ...
# 348614         2.717377         2.982793          2.684846          2.680321
# 348615         2.530524         2.864404          2.754780          2.633716
# 348616         2.099814         2.544352          2.742095          2.549021
# 348617         2.095186         2.406281          2.723665          2.508024
# 348618         2.260587         2.395556          2.773142          2.513115
#
#         Pressure  Pressure_lag1  Pressure_roll3_mean  Pressure_roll6_mean  \
# 0          843.0            NaN           843.000000           843.000000
# 1          844.0          843.0           843.500000           843.500000
# 2          843.0          844.0           843.333333           843.333333
# 3          844.0          843.0           843.666667           843.500000
# 4          844.0          844.0           843.666667           843.600000
# ...          ...            ...                  ...                  ...
# 348614     849.0          849.0           849.000000           849.333333
# 348615     849.0          849.0           849.000000           849.166667
# 348616     849.0          849.0           849.000000           849.000000
# 348617     849.0          849.0           849.000000           849.000000
# 348618     849.0          849.0           849.000000           849.000000
#
#         Pressure_roll12_mean  Pressure_roll24_mean   Temp  Temp_lag1  \
# 0                 843.000000            843.000000  22.97        NaN
# 1                 843.500000            843.500000  22.58      22.97
# 2                 843.333333            843.333333  22.84      22.58
# 3                 843.500000            843.500000  22.32      22.84
# 4                 843.600000            843.600000  21.94      22.32
# ...                      ...                   ...    ...        ...
# 348614            849.666667            850.000000  23.46      23.47
# 348615            849.583333            849.916667  23.89      23.46
# 348616            849.500000            849.833333  24.72      23.89
# 348617            849.416667            849.791667  25.12      24.72
# 348618            849.333333            849.708333  25.29      25.12
#
#         Temp_roll3_mean  Temp_roll6_mean  Temp_roll12_mean  Temp_roll24_mean  \
# 0             22.970000        22.970000         22.970000         22.970000
# 1             22.775000        22.775000         22.775000         22.775000
# 2             22.796667        22.796667         22.796667         22.796667
# 3             22.580000        22.677500         22.677500         22.677500
# 4             22.366667        22.530000         22.530000         22.530000
# ...                 ...              ...               ...               ...
# 348614        23.616667        23.715000         23.326667         22.328750
# 348615        23.606667        23.705000         23.447500         22.499583
# 348616        24.023333        23.910000         23.615833         22.699583
# 348617        24.576667        24.096667         23.825833         22.908333
# 348618        25.043333        24.325000         24.050000         23.103333
#
#           SO2  SO2_lag1  SO2_roll3_mean  SO2_roll6_mean  SO2_roll12_mean  \
# 0       25.67       NaN       25.670000       25.670000        25.670000
# 1       20.56     25.67       23.115000       23.115000        23.115000
# 2       17.24     20.56       21.156667       21.156667        21.156667
# 3       13.81     17.24       17.203333       19.320000        19.320000
# 4        9.97     13.81       13.673333       17.450000        17.450000
# ...       ...       ...             ...             ...              ...
# 348614    NaN       NaN             NaN             NaN              NaN
# 348615    NaN       NaN             NaN             NaN              NaN
# 348616    NaN       NaN             NaN             NaN              NaN
# 348617    NaN       NaN             NaN             NaN              NaN
# 348618    NaN       NaN             NaN             NaN              NaN
#
#         SO2_roll24_mean     NO2  NO2_lag1  NO2_roll3_mean  NO2_roll6_mean  \
# 0             25.670000   0.808       NaN        0.808000        0.808000
# 1             23.115000   1.167     0.808        0.987500        0.987500
# 2             21.156667   1.212     1.167        1.062333        1.062333
# 3             19.320000   1.324     1.212        1.234333        1.127750
# 4             17.450000   1.302     1.324        1.279333        1.162600
# ...                 ...     ...       ...             ...             ...
# 348614              NaN  13.670    14.000       13.796667       14.303333
# 348615              NaN  10.420    13.670       12.696667       13.380000
# 348616              NaN   8.940    10.420       11.010000       12.395000
# 348617              NaN   7.839     8.940        9.066333       11.431500
# 348618              NaN   9.660     7.839        8.813000       10.754833
#
#         NO2_roll12_mean  NO2_roll24_mean    NOX  NOX_lag1  NOX_roll3_mean  \
# 0              0.808000         0.808000  18.10       NaN       18.100000
# 1              0.987500         0.987500  17.69     18.10       17.895000
# 2              1.062333         1.062333  12.66     17.69       16.150000
# 3              1.127750         1.127750  10.92     12.66       13.756667
# 4              1.162600         1.162600  13.42     10.92       12.333333
# ...                 ...              ...    ...       ...             ...
# 348614        15.572500        14.449875  26.09     26.65       27.210000
# 348615        15.166667        14.577500  19.28     26.09       24.006667
# 348616        14.434167        14.431667  17.13     19.28       20.833333
# 348617        13.542417        14.168708  13.78     17.13       16.730000
# 348618        12.886583        14.075792  18.82     13.78       16.576667
#
#         NOX_roll6_mean  NOX_roll12_mean  NOX_roll24_mean    PM10  PM10_lag1  \
# 0            18.100000        18.100000        18.100000  131.10        NaN
# 1            17.895000        17.895000        17.895000  130.70     131.10
# 2            16.150000        16.150000        16.150000  141.30     130.70
# 3            14.842500        14.842500        14.842500  146.10     141.30
# 4            14.558000        14.558000        14.558000  146.40     146.10
# ...                ...              ...              ...     ...        ...
# 348614       30.853333        35.540000        34.878333   17.05      13.56
# 348615       27.905000        34.382500        34.992083   19.88      17.05
# 348616       24.901667        32.351667        34.350000   23.52      19.88
# 348617       21.970000        29.890833        33.401667   30.23      23.52
# 348618       20.291667        27.934167        32.962083   26.55      30.23
#
#         PM10_roll3_mean  PM10_roll6_mean  PM10_roll12_mean  PM10_roll24_mean  \
# 0            131.100000       131.100000        131.100000        131.100000
# 1            130.900000       130.900000        130.900000        130.900000
# 2            134.366667       134.366667        134.366667        134.366667
# 3            139.366667       137.300000        137.300000        137.300000
# 4            144.600000       139.120000        139.120000        139.120000
# ...                 ...              ...               ...               ...
# 348614        14.583333        17.570000         19.270083         17.912333
# 348615        16.830000        16.408333         20.623500         17.782750
# 348616        20.150000        17.356667         21.919167         18.753500
# 348617        24.543333        19.563333         23.038333         20.009917
# 348618        26.766667        21.798333         22.986667         20.835000
#
#          PM2.5  PM2.5_t+12  PM2.5_lag1  PM2.5_roll3_mean  PM2.5_roll6_mean  \
# 0       56.570      47.750         NaN         56.570000         56.570000
# 1       46.890      53.150      56.570         51.730000         51.730000
# 2       51.600      62.480      46.890         51.686667         51.686667
# 3       53.250      65.580      51.600         50.580000         52.077500
# 4       51.610      62.070      53.250         52.153333         51.984000
# ...        ...         ...         ...               ...               ...
# 348614   0.098       0.074       0.081          0.090333          0.092000
# 348615   0.105       0.098       0.098          0.094667          0.094500
# 348616   0.069       0.094       0.105          0.090667          0.091000
# 348617   0.114       0.110       0.069          0.096000          0.093167
# 348618   0.067       0.125       0.114          0.083333          0.089000
#
#         PM2.5_roll12_mean  PM2.5_roll24_mean  Location_Chicken Farm  \
# 0               56.570000          56.570000                   True
# 1               51.730000          51.730000                   True
# 2               51.686667          51.686667                   True
# 3               52.077500          52.077500                   True
# 4               51.984000          51.984000                   True
# ...                   ...                ...                    ...
# 348614           0.097417           0.100958                  False
# 348615           0.095333           0.100875                  False
# 348616           0.092167           0.099667                  False
# 348617           0.095667           0.100875                  False
# 348618           0.094750           0.099292                  False
#
#         Location_Marapong  Location_Phola  Season_Autumn  Season_Spring  \
# 0                   False           False          False          False
# 1                   False           False          False          False
# 2                   False           False          False          False
# 3                   False           False          False          False
# 4                   False           False          False          False
# ...                   ...             ...            ...            ...
# 348614              False            True          False          False
# 348615              False            True          False          False
# 348616              False            True          False          False
# 348617              False            True          False          False
# 348618              False            True          False          False
#
#         Season_Summer  Season_Winter
# 0                True          False
# 1                True          False
# 2                True          False
# 3                True          False
# 4                True          False
# ...               ...            ...
# 348614           True          False
# 348615           True          False
# 348616           True          False
# 348617           True          False
# 348618           True          False
#
# [348619 rows x 60 columns]

# %%
data_for_model['Date Time'] = pd.to_datetime(data_for_model['Date Time'])
data_for_model['Year'] = data_for_model['Date Time'].dt.year
# Out:
# C:\Users\Shivm\AppData\Local\Temp\ipykernel_22204\4097665056.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_for_model['Date Time'] = pd.to_datetime(data_for_model['Date Time'])
# C:\Users\Shivm\AppData\Local\Temp\ipykernel_22204\4097665056.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_for_model['Year'] = data_for_model['Date Time'].dt.year

# %%
data_for_model.columns
# Out:
# Index(['Hour', 'Month', 'DayOfWeek', 'Date Time', 'Wind', 'Wind_lag1',
#        'Wind_roll3_mean', 'Wind_roll6_mean', 'Wind_roll12_mean',
#        'Wind_roll24_mean', 'Pressure', 'Pressure_lag1', 'Pressure_roll3_mean',
#        'Pressure_roll6_mean', 'Pressure_roll12_mean', 'Pressure_roll24_mean',
#        'Temp', 'Temp_lag1', 'Temp_roll3_mean', 'Temp_roll6_mean',
#        'Temp_roll12_mean', 'Temp_roll24_mean', 'SO2', 'SO2_lag1',
#        'SO2_roll3_mean', 'SO2_roll6_mean', 'SO2_roll12_mean',
#        'SO2_roll24_mean', 'NO2', 'NO2_lag1', 'NO2_roll3_mean',
#        'NO2_roll6_mean', 'NO2_roll12_mean', 'NO2_roll24_mean', 'NOX',
#        'NOX_lag1', 'NOX_roll3_mean', 'NOX_roll6_mean', 'NOX_roll12_mean',
#        'NOX_roll24_mean', 'PM10', 'PM10_lag1', 'PM10_roll3_mean',
#        'PM10_roll6_mean', 'PM10_roll12_mean', 'PM10_roll24_mean', 'PM2.5',
#        'PM2.5_t+12', 'PM2.5_lag1', 'PM2.5_roll3_mean', 'PM2.5_roll6_mean',
#        'PM2.5_roll12_mean', 'PM2.5_roll24_mean', 'Location_Chicken Farm',
#        'Location_Marapong', 'Location_Phola', 'Season_Autumn', 'Season_Spring',
#        'Season_Summer', 'Season_Winter', 'Year'],
#       dtype='object')

# %%
data_for_model['PM2.5_lag1'] = data_for_model['PM2.5'].shift(1)
data_for_model['PM2.5_t+1'] = data_for_model['PM2.5'].shift(-1)
data_for_model['PM2.5_t+3'] = data_for_model['PM2.5'].shift(-3)
data_for_model['PM2.5_t+6'] = data_for_model['PM2.5'].shift(-6)
#data_for_model['PM2.5_t+12'] = data_for_model['PM2.5'].shift(-12)


# Rolling means with different windows, shifted by 1 to prevent leakage
data_for_model['PM2.5_roll3_mean'] = data_for_model['PM2.5'].rolling(window=3).mean().shift(1)
data_for_model['PM2.5_roll6_mean'] = data_for_model['PM2.5'].rolling(window=6).mean().shift(1)
data_for_model['PM2.5_roll12_mean'] = data_for_model['PM2.5'].rolling(window=12).mean().shift(1)
data_for_model['PM2.5_roll24_mean'] = data_for_model['PM2.5'].rolling(window=24).mean().shift(1)
data_for_model['PM2.5_roll3_std'] = data_for_model['PM2.5'].rolling(3).std().shift(1)
data_for_model['PM2.5_roll6_std'] = data_for_model['PM2.5'].rolling(6).std().shift(1)
data_for_model['PM2.5_roll12_std'] = data_for_model['PM2.5'].rolling(12).std().shift(1)
data_for_model['PM2.5_roll24_std'] = data_for_model['PM2.5'].rolling(24).std().shift(1)
data_for_model['PM2.5_diff1'] = data_for_model['PM2.5'] - data_for_model['PM2.5'].shift(1)
data_for_model['Temp_diff1'] = data_for_model['Temp'] - data_for_model['Temp'].shift(1)


data_for_model = data_for_model.dropna().reset_index(drop=True)
# # # Split by year
# df_train = data_for_model[data_for_model['Year'] == 2016]
# df_test = data_for_model[data_for_model['Year'] == 2017]
# df_val = data_for_model[data_for_model['Year'] == 2018]
# Out:
# C:\Users\Shivm\AppData\Local\Temp\ipykernel_22204\3330154865.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_for_model['PM2.5_lag1'] = data_for_model['PM2.5'].shift(1)
# C:\Users\Shivm\AppData\Local\Temp\ipykernel_22204\3330154865.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_for_model['PM2.5_t+1'] = data_for_model['PM2.5'].shift(-1)
# C:\Users\Shivm\AppData\Local\Temp\ipykernel_22204\3330154865.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_for_model['PM2.5_t+3'] = data_for_model['PM2.5'].shift(-3)
# C:\Users\Shivm\AppData\Local\Temp\ipykernel_22204\3330154865.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_for_model['PM2.5_t+6'] = data_for_model['PM2.5'].shift(-6)
# C:\Users\Shivm\AppData\Local\Temp\ipykernel_22204\3330154865.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_for_model['PM2.5_roll3_mean'] = data_for_model['PM2.5'].rolling(window=3).mean().shift(1)
# C:\Users\Shivm\AppData\Local\Temp\ipykernel_22204\3330154865.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_for_model['PM2.5_roll6_mean'] = data_for_model['PM2.5'].rolling(window=6).mean().shift(1)
# C:\Users\Shivm\AppData\Local\Temp\ipykernel_22204\3330154865.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_for_model['PM2.5_roll12_mean'] = data_for_model['PM2.5'].rolling(window=12).mean().shift(1)
# C:\Users\Shivm\AppData\Local\Temp\ipykernel_22204\3330154865.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_for_model['PM2.5_roll24_mean'] = data_for_model['PM2.5'].rolling(window=24).mean().shift(1)
# C:\Users\Shivm\AppData\Local\Temp\ipykernel_22204\3330154865.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_for_model['PM2.5_roll3_std'] = data_for_model['PM2.5'].rolling(3).std().shift(1)
# C:\Users\Shivm\AppData\Local\Temp\ipykernel_22204\3330154865.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_for_model['PM2.5_roll6_std'] = data_for_model['PM2.5'].rolling(6).std().shift(1)
# C:\Users\Shivm\AppData\Local\Temp\ipykernel_22204\3330154865.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_for_model['PM2.5_roll12_std'] = data_for_model['PM2.5'].rolling(12).std().shift(1)
# C:\Users\Shivm\AppData\Local\Temp\ipykernel_22204\3330154865.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_for_model['PM2.5_roll24_std'] = data_for_model['PM2.5'].rolling(24).std().shift(1)
# C:\Users\Shivm\AppData\Local\Temp\ipykernel_22204\3330154865.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_for_model['PM2.5_diff1'] = data_for_model['PM2.5'] - data_for_model['PM2.5'].shift(1)
# C:\Users\Shivm\AppData\Local\Temp\ipykernel_22204\3330154865.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_for_model['Temp_diff1'] = data_for_model['Temp'] - data_for_model['Temp'].shift(1)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr_matrix = data_for_model.corr()

# Set up the matplotlib figure
plt.figure(figsize=(20, 16))

# Generate a heatmap
sns.heatmap(corr_matrix, cmap='coolwarm', annot=False, fmt=".2f", linewidths=0.5)

# Add title
plt.title('Correlation Heatmap', fontsize=18)
plt.show()

# %%
# Compute correlations with the target
target = 'PM2.5_t+6'
correlations = data_for_model.corr()[target].drop(target)

# Sort by absolute correlation (strongest relationships first)
feature_ranking = correlations.abs().sort_values(ascending=False)

# Display top 15 features most correlated with PM2.5_t+12
print("Top correlated features with PM2.5_t+12:\n")
print(feature_ranking.head(20))
# Out:
# Top correlated features with PM2.5_t+12:
#
# PM2.5_t+3            0.790032
# PM2.5_t+1            0.660181
# PM2.5                0.626256
# PM2.5_t+12           0.618200
# PM2.5_lag1           0.596650
# PM2.5_roll3_mean     0.581426
# PM2.5_roll6_mean     0.568634
# PM2.5_roll12_mean    0.544095
# PM10                 0.500914
# PM2.5_roll24_mean    0.497677
# PM10_roll3_mean      0.486015
# PM10_lag1            0.478089
# PM10_roll6_mean      0.470021
# PM10_roll12_mean     0.442070
# NO2                  0.438188
# NO2_roll3_mean       0.430998
# NO2_lag1             0.418649
# NO2_roll6_mean       0.415151
# PM10_roll24_mean     0.400346
# NO2_roll12_mean      0.384184
# Name: PM2.5_t+6, dtype: float64

# %%
feature_ranking
# Out:
# PM2.5_t+3                0.790032
# PM2.5_t+1                0.660181
# PM2.5                    0.626256
# PM2.5_t+12               0.618200
# PM2.5_lag1               0.596650
#                            ...
# Hour                     0.064957
# Location_Chicken Farm    0.055870
# Season_Autumn            0.022493
# Month                    0.022395
# DayOfWeek                0.010218
# Name: PM2.5_t+6, Length: 69, dtype: float64

# %%
data_for_model
# Out:
#         Hour  Month  DayOfWeek           Date Time      Wind  Wind_lag1  \
# 0         20      1          4 2016-01-15 20:10:00  5.013026   6.535129
# 1         20      1          4 2016-01-15 20:20:00  4.576110   5.013026
# 2         20      1          4 2016-01-15 20:30:00  5.604620   4.576110
# 3         20      1          4 2016-01-15 20:40:00  4.630336   5.604620
# 4         20      1          4 2016-01-15 20:50:00  4.861779   4.630336
# ...      ...    ...        ...                 ...       ...        ...
# 289473    22     12          0 2017-12-11 22:50:00  1.579270   1.871147
# 289474    23     12          0 2017-12-11 23:00:00  1.250643   1.579270
# 289475    23     12          0 2017-12-11 23:10:00  1.630720   1.250643
# 289476    23     12          0 2017-12-11 23:20:00  1.238557   1.630720
# 289477    23     12          0 2017-12-11 23:30:00  1.462813   1.238557
#
#         Wind_roll3_mean  Wind_roll6_mean  Wind_roll12_mean  Wind_roll24_mean  \
# 0              5.808405         5.669708          5.005227          5.390149
# 1              5.374755         5.538088          5.002518          5.333207
# 2              5.064585         5.558342          5.178374          5.294307
# 3              4.937022         5.372713          5.245980          5.189059
# 4              5.032245         5.203500          5.324203          5.126829
# ...                 ...              ...               ...               ...
# 289473         1.752186         1.720526          1.709215          2.079104
# 289474         1.567020         1.633633          1.647748          1.992939
# 289475         1.486878         1.640574          1.665374          1.938569
# 289476         1.373307         1.562746          1.625507          1.872555
# 289477         1.444030         1.505525          1.604519          1.853200
#
#         Pressure  Pressure_lag1  Pressure_roll3_mean  Pressure_roll6_mean  \
# 0          846.0          846.0           846.000000           846.000000
# 1          847.0          846.0           846.333333           846.166667
# 2          847.0          847.0           846.666667           846.333333
# 3          847.0          847.0           847.000000           846.500000
# 4          847.0          847.0           847.000000           846.666667
# ...          ...            ...                  ...                  ...
# 289473     847.0          847.0           847.000000           847.000000
# 289474     847.0          847.0           847.000000           847.000000
# 289475     847.0          847.0           847.000000           847.000000
# 289476     847.0          847.0           847.000000           847.000000
# 289477     847.0          847.0           847.000000           847.000000
#
#         Pressure_roll12_mean  Pressure_roll24_mean   Temp  Temp_lag1  \
# 0                 846.000000            845.250000  17.53      17.60
# 1                 846.083333            845.375000  17.48      17.53
# 2                 846.166667            845.541667  17.56      17.48
# 3                 846.250000            845.666667  17.61      17.56
# 4                 846.333333            845.791667  17.63      17.61
# ...                      ...                   ...    ...        ...
# 289473            847.000000            846.541667  17.38      17.46
# 289474            847.000000            846.583333  17.23      17.38
# 289475            847.000000            846.625000  17.11      17.23
# 289476            847.000000            846.666667  17.04      17.11
# 289477            847.000000            846.708333  17.01      17.04
#
#         Temp_roll3_mean  Temp_roll6_mean  Temp_roll12_mean  Temp_roll24_mean  \
# 0             17.676667        17.860000         17.685000         19.031250
# 1             17.536667        17.763333         17.725833         18.818750
# 2             17.523333        17.676667         17.747500         18.598750
# 3             17.550000        17.613333         17.755833         18.402500
# 4             17.600000        17.568333         17.756667         18.222917
# ...                 ...              ...               ...               ...
# 289473        17.476667        17.666667         18.008333         18.836667
# 289474        17.356667        17.543333         17.880000         18.677917
# 289475        17.240000        17.418333         17.760000         18.528333
# 289476        17.126667        17.301667         17.648333         18.389583
# 289477        17.053333        17.205000         17.546667         18.262917
#
#           SO2  SO2_lag1  SO2_roll3_mean  SO2_roll6_mean  SO2_roll12_mean  \
# 0       8.150    12.060       13.016667       12.320000        10.885000
# 1       9.410     8.150        9.873333       12.226667        10.988333
# 2       9.590     9.410        9.050000       12.028333        11.012500
# 3       8.640     9.590        9.213333       11.115000        10.946667
# 4       7.702     8.640        8.644000        9.258667        10.811833
# ...       ...       ...             ...             ...              ...
# 289473  0.811     0.676        0.784667        0.850500         0.921667
# 289474  0.721     0.811        0.736000        0.814833         0.898250
# 289475  0.732     0.721        0.754667        0.767833         0.859750
# 289476  0.766     0.732        0.739667        0.762167         0.844750
# 289477  0.890     0.766        0.796000        0.766000         0.842917
#
#         SO2_roll24_mean    NO2  NO2_lag1  NO2_roll3_mean  NO2_roll6_mean  \
# 0             10.724625  1.122     0.853        1.010000        1.036167
# 1             10.260042  1.257     1.122        1.077333        1.043667
# 2              9.941292  1.324     1.257        1.234333        1.084833
# 3              9.725875  1.324     1.324        1.301667        1.155833
# 4              9.631375  1.773     1.324        1.473667        1.275500
# ...                 ...    ...       ...             ...             ...
# 289473         1.187333  2.377     2.535        2.580000        2.865500
# 289474         1.166208  2.321     2.377        2.411000        2.670167
# 289475         1.140875  2.456     2.321        2.384667        2.557500
# 289476         1.117417  2.479     2.456        2.418667        2.499333
# 289477         1.083625  2.975     2.479        2.636667        2.523833
#
#         NO2_roll12_mean  NO2_roll24_mean    NOX  NOX_lag1  NOX_roll3_mean  \
# 0              1.202667         1.286875  4.242     7.925        7.695667
# 1              1.193333         1.290625  6.268     4.242        6.145000
# 2              1.189583         1.295292  9.060     6.268        6.523333
# 3              1.215750         1.295292  7.332     9.060        7.553333
# 4              1.185750         1.314917  5.294     7.332        7.228667
# ...                 ...              ...    ...       ...             ...
# 289473         2.970667         3.874333  2.648     2.760        2.820333
# 289474         2.910583         3.686083  2.862     2.648        2.756667
# 289475         2.843917         3.611917  2.738     2.862        2.749333
# 289476         2.802583         3.544333  2.783     2.738        2.794333
# 289477         2.786667         3.456583  3.335     2.783        2.952000
#
#         NOX_roll6_mean  NOX_roll12_mean  NOX_roll24_mean    PM10  PM10_lag1  \
# 0             7.931333         7.243500         7.783167  27.390     57.750
# 1             7.707500         7.337667         7.307250   6.130     27.390
# 2             7.870833         7.486333         7.157250   4.019      6.130
# 3             7.624500         7.489167         7.007750   4.064      4.019
# 4             6.686833         7.376250         6.669167   4.042      4.064
# ...                ...              ...              ...     ...        ...
# 289473        3.113500         3.269417         4.316708  19.250     22.450
# 289474        2.985833         3.230917         4.110167  15.410     19.250
# 289475        2.875000         3.166167         4.027542  14.870     15.410
# 289476        2.807333         3.114500         3.951958  14.540     14.870
# 289477        2.854333         3.100417         3.853375  18.830     14.540
#
#         PM10_roll3_mean  PM10_roll6_mean  PM10_roll12_mean  PM10_roll24_mean  \
# 0             53.926667        81.613333         88.217500        102.378750
# 1             30.423333        63.201667         82.490000         97.188333
# 2             12.513000        45.054833         76.335750         91.468292
# 3              4.737667        29.332167         69.607750         85.550125
# 4              4.041667        17.232500         61.644583         79.618542
# ...                 ...              ...               ...               ...
# 289473        24.020000        25.358333         37.663333         40.919167
# 289474        19.036667        23.353333         33.260833         39.832917
# 289475        16.510000        21.420000         29.080833         38.557083
# 289476        14.940000        19.480000         25.494167         37.439583
# 289477        16.080000        17.558333         23.150000         36.619167
#
#          PM2.5  PM2.5_t+12  PM2.5_lag1  PM2.5_roll3_mean  PM2.5_roll6_mean  \
# 0       13.810       0.406      31.680         41.970000         49.580000
# 1        4.857       0.377      13.810         29.956667         42.018333
# 2        4.540       0.914       4.857         16.782333         33.312833
# 3        7.338       3.009       4.540          7.735667         24.852833
# 4       19.630       8.110       7.338          5.578333         17.767500
# ...        ...         ...         ...               ...               ...
# 289473  24.660       0.087      34.900         53.970000         64.996667
# 289474  15.620       0.078      24.660         37.500000         58.071667
# 289475  12.350       0.065      15.620         25.060000         47.498333
# 289476   3.836       0.085      12.350         17.543333         35.756667
# 289477   0.195       0.069       3.836         10.602000         24.051000
#
#         PM2.5_roll12_mean  PM2.5_roll24_mean  Location_Chicken Farm  \
# 0               54.111667          48.655417                   True
# 1               51.283333          46.873750                   True
# 2               47.258917          45.122375                   True
# 3               42.430583          43.161542                   True
# 4               37.577083          41.248542                   True
# ...                   ...                ...                    ...
# 289473          51.169167          49.799167                  False
# 289474          48.290000          48.068333                  False
# 289475          46.880000          46.241667                  False
# 289476          46.183333          45.237917                  False
# 289477          43.661333          44.205667                  False
#
#         Location_Marapong  Location_Phola  Season_Autumn  Season_Spring  \
# 0                   False           False          False          False
# 1                   False           False          False          False
# 2                   False           False          False          False
# 3                   False           False          False          False
# 4                   False           False          False          False
# ...                   ...             ...            ...            ...
# 289473              False            True          False          False
# 289474              False            True          False          False
# 289475              False            True          False          False
# 289476              False            True          False          False
# 289477              False            True          False          False
#
#         Season_Summer  Season_Winter  Year  PM2.5_t+1  PM2.5_t+3  PM2.5_t+6  \
# 0                True          False  2016      4.857      7.338     22.230
# 1                True          False  2016      4.540     19.630     16.570
# 2                True          False  2016      7.338     27.300     12.030
# 3                True          False  2016     19.630     22.230      8.160
# 4                True          False  2016     27.300     16.570      5.870
# ...               ...            ...   ...        ...        ...        ...
# 289473           True          False  2017     15.620      3.836      0.110
# 289474           True          False  2017     12.350      0.195      0.112
# 289475           True          False  2017      3.836      0.049      0.078
# 289476           True          False  2017      0.195      0.110      0.098
# 289477           True          False  2017      0.049      0.112      0.063
#
#         PM2.5_roll3_std  PM2.5_roll6_std  PM2.5_roll12_std  PM2.5_roll24_std  \
# 0              9.321658        10.283982          9.550991         10.983233
# 1             15.357690        16.571430         15.048998         12.937813
# 2             13.656295        20.357587         20.110523         15.522344
# 3              5.262914        19.935734         22.887542         17.513206
# 4              1.532137        16.540054         23.693405         18.821940
# ...                 ...              ...               ...               ...
# 289473        19.605303        18.164284         20.806476         18.065706
# 289474        14.318156        24.444005         21.951620         18.412656
# 289475         9.646222        27.123453         23.541103         19.382465
# 289476         6.376397        23.834453         24.490530         20.503479
# 289477         6.083362        17.716023         27.250706         21.949635
#
#         PM2.5_diff1  Temp_diff1
# 0           -17.870       -0.07
# 1            -8.953       -0.05
# 2            -0.317        0.08
# 3             2.798        0.05
# 4            12.292        0.02
# ...             ...         ...
# 289473      -10.240       -0.08
# 289474       -9.040       -0.15
# 289475       -3.270       -0.12
# 289476       -8.514       -0.07
# 289477       -3.641       -0.03
#
# [289478 rows x 70 columns]

# %%
features = [
    "PM2.5_t+3",
    "PM2.5_t+1",
    "PM2.5",
    "PM2.5_lag1",
    "PM2.5_roll3_mean",
    "PM2.5_roll6_mean",
    "PM2.5_roll12_mean",
    "PM10",
    "PM2.5_roll24_mean",
    "PM10_roll3_mean",
    "PM10_lag1",
    "PM10_roll6_mean",
    "PM10_roll12_mean",
    "NO2",
    "NO2_roll3_mean",
    "NO2_lag1",
    "NO2_roll6_mean",
    "PM10_roll24_mean",
    "NO2_roll12_mean",
]

# %%
# data_for_model = data_for_model.dropna()
# data_for_model.drop(columns=['PM2.5_lag1', 'PM2.5_roll3_mean', 'PM2.5_roll6_mean',
#        'PM2.5_roll12_mean', 'PM2.5_roll24_mean'], inplace=True)

# data_for_model

# %%
X = data_for_model[features]
y = data_for_model['PM2.5_t+6']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X
# Out:
#         PM2.5_t+3  PM2.5_t+1   PM2.5  PM2.5_lag1  PM2.5_roll3_mean  \
# 0           7.338      4.857  13.810      31.680         41.970000
# 1          19.630      4.540   4.857      13.810         29.956667
# 2          27.300      7.338   4.540       4.857         16.782333
# 3          22.230     19.630   7.338       4.540          7.735667
# 4          16.570     27.300  19.630       7.338          5.578333
# ...           ...        ...     ...         ...               ...
# 289473      3.836     15.620  24.660      34.900         53.970000
# 289474      0.195     12.350  15.620      24.660         37.500000
# 289475      0.049      3.836  12.350      15.620         25.060000
# 289476      0.110      0.195   3.836      12.350         17.543333
# 289477      0.112      0.049   0.195       3.836         10.602000
#
#         PM2.5_roll6_mean  PM2.5_roll12_mean    PM10  PM2.5_roll24_mean  \
# 0              49.580000          54.111667  27.390          48.655417
# 1              42.018333          51.283333   6.130          46.873750
# 2              33.312833          47.258917   4.019          45.122375
# 3              24.852833          42.430583   4.064          43.161542
# 4              17.767500          37.577083   4.042          41.248542
# ...                  ...                ...     ...                ...
# 289473         64.996667          51.169167  19.250          49.799167
# 289474         58.071667          48.290000  15.410          48.068333
# 289475         47.498333          46.880000  14.870          46.241667
# 289476         35.756667          46.183333  14.540          45.237917
# 289477         24.051000          43.661333  18.830          44.205667
#
#         PM10_roll3_mean  PM10_lag1  PM10_roll6_mean  PM10_roll12_mean    NO2  \
# 0             53.926667     57.750        81.613333         88.217500  1.122
# 1             30.423333     27.390        63.201667         82.490000  1.257
# 2             12.513000      6.130        45.054833         76.335750  1.324
# 3              4.737667      4.019        29.332167         69.607750  1.324
# 4              4.041667      4.064        17.232500         61.644583  1.773
# ...                 ...        ...              ...               ...    ...
# 289473        24.020000     22.450        25.358333         37.663333  2.377
# 289474        19.036667     19.250        23.353333         33.260833  2.321
# 289475        16.510000     15.410        21.420000         29.080833  2.456
# 289476        14.940000     14.870        19.480000         25.494167  2.479
# 289477        16.080000     14.540        17.558333         23.150000  2.975
#
#         NO2_roll3_mean  NO2_lag1  NO2_roll6_mean  PM10_roll24_mean  \
# 0             1.010000     0.853        1.036167        102.378750
# 1             1.077333     1.122        1.043667         97.188333
# 2             1.234333     1.257        1.084833         91.468292
# 3             1.301667     1.324        1.155833         85.550125
# 4             1.473667     1.324        1.275500         79.618542
# ...                ...       ...             ...               ...
# 289473        2.580000     2.535        2.865500         40.919167
# 289474        2.411000     2.377        2.670167         39.832917
# 289475        2.384667     2.321        2.557500         38.557083
# 289476        2.418667     2.456        2.499333         37.439583
# 289477        2.636667     2.479        2.523833         36.619167
#
#         NO2_roll12_mean
# 0              1.202667
# 1              1.193333
# 2              1.189583
# 3              1.215750
# 4              1.185750
# ...                 ...
# 289473         2.970667
# 289474         2.910583
# 289475         2.843917
# 289476         2.802583
# 289477         2.786667
#
# [289478 rows x 19 columns]

# %%
# Let's use 80% of the data for training, 20% for testing
split_idx = int(len(X_scaled) * 0.8)

X_train, X_test = X_scaled[:split_idx], X_scaled[split_idx:]
y_train, y_test = y[:split_idx], y[split_idx:]

# %%
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')

early_stop = EarlyStopping(patience=10, restore_best_weights=True)

model.fit(X_train, y_train, validation_data=(X_test, y_test),
          epochs=50, batch_size=32, callbacks=[early_stop], verbose=1)
# Out:
# c:\Users\Shivm\Documents\Masters\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - loss: 257.4815 - val_loss: 756.7863
# Epoch 2/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - loss: 179.2388 - val_loss: 746.2947
# Epoch 3/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 34s 5ms/step - loss: 176.0787 - val_loss: 750.5441
# Epoch 4/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - loss: 171.3432 - val_loss: 766.4618
# Epoch 5/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - loss: 167.6953 - val_loss: 748.8529
# Epoch 6/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - loss: 174.6325 - val_loss: 767.6310
# Epoch 7/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - loss: 167.5950 - val_loss: 743.7069
# Epoch 8/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - loss: 168.5675 - val_loss: 794.6282
# Epoch 9/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - loss: 167.2859 - val_loss: 743.6447
# Epoch 10/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - loss: 169.4137 - val_loss: 774.3838
# Epoch 11/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - loss: 166.4009 - val_loss: 761.0159
# Epoch 12/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - loss: 158.5692 - val_loss: 751.9298
# Epoch 13/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - loss: 167.7105 - val_loss: 759.4173
# Epoch 14/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - loss: 163.7435 - val_loss: 770.4789
# Epoch 15/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - loss: 164.3088 - val_loss: 758.6942
# Epoch 16/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - loss: 164.2366 - val_loss: 770.4982
# Epoch 17/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - loss: 166.6597 - val_loss: 742.9963
# Epoch 18/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - loss: 159.3366 - val_loss: 746.5334
# Epoch 19/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - loss: 160.7434 - val_loss: 745.0656
# Epoch 20/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 690s 95ms/step - loss: 162.9897 - val_loss: 746.2310
# Epoch 21/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 161.6068 - val_loss: 748.5325
# Epoch 22/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - loss: 165.1949 - val_loss: 749.7410
# Epoch 23/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - loss: 156.7962 - val_loss: 766.1683
# Epoch 24/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - loss: 163.9361 - val_loss: 746.8773
# Epoch 25/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 160.5300 - val_loss: 749.8795
# Epoch 26/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - loss: 156.1694 - val_loss: 750.4623
# Epoch 27/50
# 7237/7237 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 160.9613 - val_loss: 769.1319

# %%
y_pred = model.predict(X_test).flatten()

r2 = r2_score(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)

print(f"R²: {r2}")
print(f"RMSE: {rmse}")
# Out:
# 1810/1810 ━━━━━━━━━━━━━━━━━━━━ 1s 703us/step
# R²: 0.5930115099256696
# RMSE: 27.257956006499906
# c:\Users\Shivm\Documents\Masters\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
last_known_data = data_for_model.iloc[-1][features].values.reshape(1, -1)
last_known_data_scaled = scaler.transform(last_known_data)

forecast_24hr = model.predict(last_known_data_scaled)[0][0]
print(f"Forecasted PM2.5 (24 hrs ahead): {forecast_24hr}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Forecasted PM2.5 (24 hrs ahead): 8.951014518737793
# c:\Users\Shivm\Documents\Masters\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score

# Assuming y_test and y_pred are already inverse transformed to the original scale
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.5, edgecolor=None)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # ideal line
plt.xlabel('Actual PM2.5')
plt.ylabel('Predicted PM2.5')
plt.title(f'Actual vs Predicted PM2.5 (R² = {r2_score(y_test, y_pred):.2f})')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# ---------------------------
# 7️⃣ Plot Loss Curves
# ---------------------------
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Training & Validation Loss')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       1 # ---------------------------
#       2 # 7️⃣ Plot Loss Curves
#       3 # ---------------------------
# ----> 4 plt.plot(history.history['loss'], label='Training Loss')
#       5 plt.plot(history.history['val_loss'], label='Validation Loss')
#       6 plt.legend()
#
# NameError: name 'history' is not defined

# %%
y_test_inverse = scaler_y.inverse_transform(y_test)
y_pred = model.predict(X_test)
y_pred_inverse = scaler_y.inverse_transform(y_pred)

plt.figure(figsize=(12, 6))
plt.plot(y_test_inverse.flatten(), label='True PM2.5')
plt.plot(y_pred_inverse.flatten(), label='Predicted PM2.5', linestyle='--')
plt.title('LSTM Predictions vs True Values (Original Scale)')
plt.xlabel('Time Step')
plt.ylabel('PM2.5')
plt.legend()
plt.show()
# Out:
# 1810/1810 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step

# %%
y_pred = model.predict(X_test)
X_test
y_test_rescaled = scaler_y.inverse_transform(y_test)
y_pred_rescaled = scaler_y.inverse_transform(y_pred)

from sklearn.metrics import mean_squared_error, r2_score
print('R²:', r2_score(y_test_rescaled, y_pred_rescaled))
print('RMSE:', mean_squared_error(y_test_rescaled, y_pred_rescaled, squared=False))
# Out:
# 1810/1810 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# R²: 0.807124999766248
# RMSE: 19.160525541171367
# c:\Users\Shivm\Documents\Masters\.venv\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
import numpy as np

# Predict on test data
y_pred = model.predict(X_test)

# Inverse transform if scaling was applied to y
# Make sure scaler was fitted on y_train originally
y_test_inverse = scaler_y.inverse_transform(y_test.reshape(-1, 1))
y_pred_inverse = scaler_y.inverse_transform(y_pred)

# Flatten for plotting
y_test_flat = y_test_inverse.flatten()
y_pred_flat = y_pred_inverse.flatten()

# Plot predictions vs true values
plt.figure(figsize=(12, 6))
plt.plot(y_test_flat, label='True Values', color='blue')
plt.plot(y_pred_flat, label='Predicted Values', color='red', linestyle='--')
plt.title('LSTM Predictions vs True Values (Inverse Transformed)')
plt.xlabel('Time Step')
plt.ylabel('Target Variable (Original Scale)')
plt.legend()
plt.show()
# Out:
# 1810/1810 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step

# %%
import seaborn as sns

plt.figure(figsize=(6, 6))
sns.scatterplot(x=y_test_flat, y=y_pred_flat, alpha=0.6)
plt.plot([y_test_flat.min(), y_test_flat.max()], [y_test_flat.min(), y_test_flat.max()], 'r--')
plt.title('True vs Predicted (Original Scale)')
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       1 import seaborn as sns
#       3 plt.figure(figsize=(6, 6))
# ----> 4 sns.scatterplot(x=y_test_flat, y=y_pred_flat, alpha=0.6)
#       5 plt.plot([y_test_flat.min(), y_test_flat.max()], [y_test_flat.min(), y_test_flat.max()], 'r--')
#       6 plt.title('True vs Predicted (Original Scale)')
#
# NameError: name 'y_test_flat' is not defined
